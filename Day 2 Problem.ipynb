# %% [markdown]
# # <span style='background :beige'><span style='font-family:"Times New Roman"'>Q2. Determine the total capital outlay required for OLA to sustain operations. In addition, Capital outlay required to expand its venture, say OLA Money, to build as a new generation payment app, equivalent to Google Pay, is around INR 1000 Crores (approx).
# </span>

# %% [markdown]
# ## <span style='background :paleturquoise'><span style='font-family:"Times New Roman"'>Importing Necessary Libraries</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## <span style='background :palegreen'><span style='font-family:"Times New Roman"'>Covid scenario  across operating countries of OLA </span>
# ## https://ourworldindata.org/coronavirus-data-explorer

# %%
data2=pd.read_csv(r"Necessary_Files\daily_active.csv")
plt.figure(figsize=(9,5))
sns.lineplot(data=data2,lw=2.5)
plt.title("Daily Active Cases 25th March - 5th August",size=18)
plt.xlabel("Number of Days",size=18)
plt.ylabel("Number of Cases",size=18)
plt.xticks(size=14)
plt.yticks(size=14)
plt.show()

# %%
pred=pd.read_csv(r"Necessary_Files\indiacovid.csv")
plt.figure(figsize=(9,5))
sns.lineplot(data=pred,lw=3)
plt.title("Daily Active vs Cured Cases: India 25th March - 5th August",size=18)
plt.xlabel("Number of Days",size=18)
plt.ylabel("Number of Cases",size=18)
plt.xticks(size=14)
plt.yticks(size=14)
plt.show()

# %% [markdown]
# ## <span style='background :palegreen'><span style='font-family:"Times New Roman"'>Estimation Model </span>

# %%
data3=pd.DataFrame()
data3['Estimating Conditions']=['if slope > 0','if slope < 0','if slope ==0']
data3['Duration']=['After x days','After y days','After z days']
data3['Prediction']=['Uncertain','Lockdown may get over after 0.7y days','Lockdown may get over completely']
data3['Flag']=['Red Flag 🔴','Orange Flag 🟠','Green Flag 🟢']
data3['return into normalcy percentage']=['10-20%','50-60%','80-90%']
data3
# Out:
#   Estimating Conditions      Duration                             Prediction  \
# 0          if slope > 0  After x days                              Uncertain
# 1          if slope < 0  After y days  Lockdown may get over after 0.7y days
# 2          if slope ==0  After z days       Lockdown may get over completely
#
#             Flag return into normalcy percentage
# 0     Red Flag 🔴                          10-20%
# 1  Orange Flag 🟠                          50-60%
# 2   Green Flag 🟢                          80-90%

# %% [markdown]
# ## <span style='background :palegreen'><span style='font-family:"Times New Roman"'>Cost of Running Operations till normalcy </span>

# %%
days=int(input('Enter Number of Days (lockdown effect) : '))
months=days/30
print('Approximate: ',round(months,2),'Months')
# Out:
# Enter Number of Days (lockdown effect) : 95
# Approximate:  3.17 Months

# %% [markdown]
# # <span style='background :khaki'><span style='font-family:"Times New Roman"'>Overall Monthly Cost for running Operations of OLA : ₹450 Crores </span>

# %%
print('Total cost required : ',450*3.17,'Crores')
# Out:
# Total cost required :  1426.5 Crores

# %% [markdown]
# ![](Necessary_Files\wallets.png)

# %% [markdown]
# # <span style='background :paleturquoise'><span style='font-family:"Times New Roman"'>Sum of capital required to run the operations and additional investments in OLA Money</span>

# %% [markdown]
# ![](Necessary_Files\olamoney.png)

# %%
data4=pd.DataFrame()
data4['Keypoints']=['Varied Options','Money Transfer','Best for “On the Move” Payments','Money Saving','Guaranteed Refunds','Expansive Services','Offers more Convenience']
data4['Featured']=['You can use the PayTm wallet for a number of things','You can use this wallet to send money to your loved ones and receive it from them too.','You can use PayTm mobile website or the app to pay bills or recharge when you are on the move.','The wallet also allows you to save your hard earned money by offering various cashback schemes on a regular basis.',' If for any reason, you are not satisfied with the PayTm wallet services, you can get your money back within a few hours.','Working more and more to expand its services for its users',' They recently liaised with Bank of Maharashtra and it now allows the customers to use their debit card to top up their PayTm wallet']

# %% [markdown]
# ## https://bestapk.com/advantages-of-using-paytm-wallet/

# %%
data4
# Out:
#                          Keypoints  \
# 0                   Varied Options
# 1                   Money Transfer
# 2  Best for “On the Move” Payments
# 3                     Money Saving
# 4               Guaranteed Refunds
# 5               Expansive Services
# 6          Offers more Convenience
#
#                                             Featured
# 0  You can use the PayTm wallet for a number of t...
# 1  You can use this wallet to send money to your ...
# 2  You can use PayTm mobile website or the app to...
# 3  The wallet also allows you to save your hard e...
# 4   If for any reason, you are not satisfied with...
# 5  Working more and more to expand its services f...
# 6   They recently liaised with Bank of Maharashtr...

# %% [markdown]
# ## The average cost to develop such an app on both platforms is approx 12 lakh INR at 3700 INR per hour.
